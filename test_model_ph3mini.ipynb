# %%
import requests
import time

# %%
url = "http://localhost:11434/api/generate"

# %%
prompts = [
        "Explain quantum computing in 5 sentences.",
        "Write a python script to reverse a linked list.",
        "Summarize the plot of the Matrix."
    ]

# %%
payload = {
    "model": "phi3:mini",
    "prompt": '''"Explain quantum computing in 5 sentences.",
        "Write a python script to reverse a linked list.",
        "Summarize the plot of the Matrix."''',
    "stream": False
}

# %%
start = time.time()
response = requests.post(url = url, json = payload)
end = time.time()

# %%
response.json()["response"]
# Out:
# "\nQuantum computing uses the principles of quantum mechanics, such as superposition and entanglement, to process information. Unlike classical bits, quantum bits, or qubits, can exist in multiple states simultaneously. This allows quantum computers to perform many calculations at once, potentially solving complex problems much faster than traditional computers. However, quantum computing is still in the experimental stage and faces challenges like error correction and qubit stability. Despite these hurdles, quantum computing holds promise for revolutionizing fields such as cryptography, optimization, and drug discovery.\n\n\nHere' extrinsic code to reverse a linked list in Python:\n\n\n```python\n\nclass ListNode:\n\n    def __init__(self, value=0, next=None):\n\n        self.value = value\n\n        self.next = next\n\n\ndef reverse_linked_list(head):\n\n    previous = None\n\n    current = head\n\n    while current:\n\n        next_temp = current.next\n\n        current.next = previous\n\n        previous = current\n\n        current = next_temp\n\n    return previous\n\n\n# Example usage:\n\n# Create a linked list 1 -> 2 -> 3 -> 4 -> 5\n\nnode_1 = ListNode(1)\n\nnode_2 = ListNode(2, node_1)\n\nnode_3 = ListNode(3, nodes_2)\n\nnode_4 = ListNode(4, node_3)\n\nnode_5 = ListNode(5, node_4)\n\n\nreversed_list = reverse_linked_list(node_5)\n\n# Now the list is 5 -> 4 -> 3 -> 2 -> 1 and should be traversed from here\n\n```\n\n\nThe Matrix, directed by The Wachowskis, presents a dystopian future where reality is governed by a simulated world called the Matrix, created by sentient machines to subdue the human population. Within this Matrix, the protagonist Thomas Anderson/Neo discovers his latent abilities and learns that he's 'The One' prophesied to free humanity. The movie unfolds Neo's journey to understand his role in the rebellion against the machines, as he navigates various layers of the Matrix and encounters Morpheus, Trinity, and the Oracle. Along the way, Neo's actions and decisions significantly alter the Matrix's reality, leading to a climactic showdown between humans and machines. Ultimately, the movie explores themes of destiny, choice, and the nature of reality itself."
